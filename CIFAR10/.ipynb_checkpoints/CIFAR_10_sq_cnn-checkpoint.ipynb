# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras import datasets,models,layers

# %%
data = tf.keras.datasets.cifar10
# The CIFAR10 dataset contains 60,000 color images in 10 classes, 
# with 6,000 images in each class. The dataset is divided into 50,000 training
# images and 10,000 testing images.

# %%
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %%
print(train_labels[0])
# Out:
# [6]

# %%
print(train_images[1])
# Out:
# [[[154 177 187]
#   [126 137 136]
#   [105 104  95]
#   ...
#   [ 91  95  71]
#   [ 87  90  71]
#   [ 79  81  70]]
#
#  [[140 160 169]
#   [145 153 154]
#   [125 125 118]
#   ...
#   [ 96  99  78]
#   [ 77  80  62]
#   [ 71  73  61]]
#
#  [[140 155 164]
#   [139 146 149]
#   [115 115 112]
#   ...
#   [ 79  82  64]
#   [ 68  70  55]
#   [ 67  69  55]]
#
#  ...
#
#  [[175 167 166]
#   [156 154 160]
#   [154 160 170]
#   ...
#   [ 42  34  36]
#   [ 61  53  57]
#   [ 93  83  91]]
#
#  [[165 154 128]
#   [156 152 130]
#   [159 161 142]
#   ...
#   [103  93  96]
#   [123 114 120]
#   [131 121 131]]
#
#  [[163 148 120]
#   [158 148 122]
#   [163 156 133]
#   ...
#   [143 133 139]
#   [143 134 142]
#   [143 133 144]]]

# %%
plt.figure()
plt.imshow(train_images[20])
plt.colorbar()
plt.grid(False)

plt.show()

# %%
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(train_images[i])
plt.show()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = tf.keras.models.Sequential([
                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                        tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(128, activation='relu'),
                        tf.keras.layers.Dense(10, activation='softmax')])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5004 - accuracy: 0.4555 - val_loss: 1.2153 - val_accuracy: 0.5678
# Epoch 2/20
# 1563/1563 [==============================] - 57s 36ms/step - loss: 1.1122 - accuracy: 0.6058 - val_loss: 1.0300 - val_accuracy: 0.6334
# Epoch 3/20
# 1563/1563 [==============================] - 32s 21ms/step - loss: 0.9680 - accuracy: 0.6595 - val_loss: 0.9610 - val_accuracy: 0.6583
# Epoch 4/20
# 1563/1563 [==============================] - 32s 21ms/step - loss: 0.8777 - accuracy: 0.6936 - val_loss: 0.9086 - val_accuracy: 0.6804
# Epoch 5/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.8056 - accuracy: 0.7194 - val_loss: 0.8692 - val_accuracy: 0.6980
# Epoch 6/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.7398 - accuracy: 0.7403 - val_loss: 0.8773 - val_accuracy: 0.6928
# Epoch 7/20
# ...

# %%
scores_train = model.evaluate(train_images, train_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores_train[1]*100))
scores_test = model.evaluate(test_images, test_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# Accuracy: 93.13%
# Accuracy: 69.36%

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
sqmodel = tf.keras.models.Sequential([
                        tf.keras.layers.Flatten( input_shape=(32, 32, 3)),
                        tf.keras.layers.Dense(512, activation='relu'),
                        tf.keras.layers.Dense(12, activation='softmax')])

sqmodel.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history2 = sqmodel.fit(train_images, train_labels, epochs=20, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.8901 - accuracy: 0.3286 - val_loss: 1.7323 - val_accuracy: 0.3847
# Epoch 2/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.6875 - accuracy: 0.3974 - val_loss: 1.6652 - val_accuracy: 0.4085
# Epoch 3/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.6222 - accuracy: 0.4203 - val_loss: 1.6011 - val_accuracy: 0.4355
# Epoch 4/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5798 - accuracy: 0.4367 - val_loss: 1.5887 - val_accuracy: 0.4331
# Epoch 5/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5461 - accuracy: 0.4488 - val_loss: 1.5527 - val_accuracy: 0.4402
# Epoch 6/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5192 - accuracy: 0.4593 - val_loss: 1.5696 - val_accuracy: 0.4379
# Epoch 7/20
# ...

# %%
scores_train = sqmodel.evaluate(train_images, train_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores_train[1]*100))
scores_test = sqmodel.evaluate(test_images, test_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores_test[1]*100))
# Out:
# Accuracy: 51.91%
# Accuracy: 47.20%

# %%
plt.plot(history2.history['accuracy'], label='accuracy')
plt.plot(history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.0, 1])
plt.legend(loc='lower right')
